# %% [markdown]
# ---
# title: "title"
# subtitle: "a subtitle"
# format:
#   html: default
#   pdf: default
# ---

# %% [markdown]
# {{< include extras/_lecture-header.html >}}

# %% [markdown]
# ::: {.callout-note}
# A note
# :::
#
# ::: {.callout-tip collapse=false}
# # A tip
#
# Words
# :::
#
# ::: {.callout-important}
#
# Important words
#
# :::
#
# ::: {.callout-warning}
#
# a warning
# :::
#
# ::: {.callout-caution}
# caution
# :::

# %% [markdown]
# ::: {#exm-label}
#
# :::

# %% [markdown]
# ::: {#exr-label}
#
# :::

# %% [markdown]
# ::: {#thm-label collapse=false}
# # Theorem
#
# :::
#
# ::: {#lem-label}
# # Lemma
#
# :::
#
# ::: {#cor-label}
# # Corollary
#
# :::
#
# ::: {#prp-label}
# # Proposition
#
# :::
#
# ::: {#cnj-label}
# # Conjecture
#
# :::
#
# ::: {#def-label}
# # Definition
#
# :::
#
# ::: {#exm-label}
# # Example
#
# :::
#
# ::: {#exr-label}
# # Exercise
#
# :::
#
# ::: {#sol-label}
# # Solution
#
# :::
#
# ::: {#rem-label}
# # Remark
#
# :::

# %% [markdown]
# @thm-label
#
# @lem-label
#
# @cor-label
#
# @prp-label
#
# @cnj-label
#
# @def-label
#
# @exm-label
#
# @exr-label
#
# @sol-label
#
# @rem-label
