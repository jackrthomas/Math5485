# %% [markdown]
# # Introduction
#
# <a href="lecture01.ipynb" download="lecture01.ipynb" class="btn btn-primary" role="button">
#   <i class="bi bi-download"></i> Download (.ipynb)
# </a>

# %%
1+1
# Out:
# 2
