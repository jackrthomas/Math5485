# %% [markdown]
# ---
# title: "Introduction"
# subtitle: "Lecture 1: Introduction to Math5485"
# date: 2026-09-09
# abstract-title: Overview
# abstract: |
#   (1) Syllabus, Canvas, website, and admin; </br>
#   (2) Intro to notebooks; </br>
#   (3) Overview of Math5485; </br>
#   (4) Intro to Numerical Analysis; </br>
#   (5) Exercises
# format:
#   html:
#     code-copy: true
# ---
#
# {{< include ../extras/_lecture-header.html >}}

# %% [markdown]
# ## Notebooks
#
# This website is created using Jupyter Notebooks. They allow you to include Markdown, $\LaTeX$, and Julia (as well as python and other languages).
#
# ::: {.callout-tip}
#
# Follow the steps in <a href="appendix/installing-julia.html">installing-julia.html</a> and <a href="assignments/A1.html">A1</a> to learn about notebooks and Julia.
#
# :::
#
# Notebooks are made up from "cells".
#
# * ```A``` adds a cell above the currently selected cell,
# * ```B``` adds a cell below,
# * ```M``` changes the cell from Julia to markdown,
# * ```Y``` changes the cell from markdown to Julia,
# * Double click or ```enter``` to see the syntax and edit cells,
# * Press ```ctrl```+```enter``` to exit edit mode,
#
# ::: {#exr-1 .no-solution}
#
# [](../exercises/bank.html#bank-exr-1)
#
# Add a new markdown cell below this one and write "Hello world!"
#
# :::

# %% [markdown]
# ## Markdown
#
# Text in this cell can be **bold**, *italic*, ***bold italic***, quotes
#
# >"The only source of knowledge is experience"
# >-- Einstein
#
# ```
# Preformatted text,
#     useful for
# pseudocode
# ```
#
# * Bullet points
#     - level 2 bullet points
#     - etc..
# * Another point
#
# <div style="border: 2px solid red; padding: 10px 0px 10px 10px">You can also use normal html formatting if you are familiar with that...</div>
#
# Markdown cheat sheet: <a href="https://www.markdownguide.org/basic-syntax/"
#      class="btn btn-outline-success btn-sm"
#      target="_blank"
#      rel="noopener noreferrer">
#     <i class="bi bi-box-arrow-up-right me-1" aria-hidden="true"></i>
#     link
#     <span class="visually-hidden">(opens in a new tab)</span>
#   </a>

# %% [markdown]
# ## $\LaTeX$
#
# $\LaTeX$ allows you to display math: e.g. $\pi \approx \frac{22}{7}$ and $$f(x) = f(a) + f'(a) (x - a) + \frac{1}{2} f''(a) (x-a)^2 + R(x).$$
#
# Multi-line equations are also possible:
#
# $$
# \begin{align}
#     \int_a^b f(x) \mathrm{d}x
#     %
#     &\approx \int_a^b p_n(x) \mathrm{d}x \nonumber \\
#     %
#     &= \sum_{j=0}^n w_j f(x_j)
# \end{align}
# $$ {#eq-1}
#
# $\LaTeX$ cheat sheet: <a href="https://quickref.me/latex.html"
#      class="btn btn-outline-success btn-sm"
#      target="_blank"
#      rel="noopener noreferrer">
#     <i class="bi bi-box-arrow-up-right me-1" aria-hidden="true"></i>
#     link
#     <span class="visually-hidden">(opens in a new tab)</span>
#   </a>
#
# Draw symbol to get $\LaTeX$ syntax: <a href="https://detexify.kirelabs.org/classify.html"
#      class="btn btn-outline-success btn-sm"
#      target="_blank"
#      rel="noopener noreferrer">
#     <i class="bi bi-box-arrow-up-right me-1" aria-hidden="true"></i>
#     link
#     <span class="visually-hidden">(opens in a new tab)</span>
#   </a>

# %% [markdown]
# ## Julia

# %%
1+1
# Out:
# 2

# %% [markdown]
# You can use greek symbols in Julia code: type ```\pi``` and ```tab``` to get the symbol.

# %%
π
# Out:
# π = 3.1415926535897...

# %% [markdown]
# You can add comments with a ```#```:

# %%
# Define p
p = 22/7;

# %% [markdown]
# You can also use ```@show``` to print variables (which also prints the calculation):

# %%
@show abs(π-p)/π;
# Out:
# abs(π - p) / π = 0.0004024994347707008

# %% [markdown]
# You can use ```println()``` to output variables (and you can also add text):

# %%
println( "The relative error when approximating π by 22/7 is ", abs(π-p)/π)
# Out:
# The relative error when approximating π by 22/7 is 0.0004024994347707008

# %% [markdown]
# ### Arrays, vectors, and matrices
#
# Arrays start at 1:

# %%
a = [1 2 3 4 5]
# Out:
# 1×5 Matrix{Int64}:
#  1  2  3  4  5

# %%
a[1]
# Out:
# 1

# %% [markdown]
# Vectors:

# %%
b = [2, 4, 6, 8]
# Out:
# 4-element Vector{Int64}:
#  2
#  4
#  6
#  8

# %% [markdown]
# Vector of objects:

# %%
c = [ a , b , "hello world" ]
# Out:
# 3-element Vector{Any}:
#  [1 2 … 4 5]
#  [2, 4, 6, 8]
#  "hello world"

# %%
c[3]
# Out:
# "hello world"

# %% [markdown]
# Matrices
#
# You can either specify the columns:

# %%
X = [ [1, 4] [2, 5] ]
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  4  5

# %% [markdown]
# Or the rows:

# %%
Y = [ 1 2 ; 4 5 ]
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  4  5

# %% [markdown]
# ### Linear Algebra {.unnumbered}
#
# In order to use a certain package, you need to use the ```using``` keyword:

# %%
using LinearAlgebra

# %% [markdown]
# Recall that

# %%
X
# Out:
# 2×2 Matrix{Int64}:
#  1  2
#  4  5

# %%
det( X )
# Out:
# -3.0

# %%
tr( X )
# Out:
# 6

# %%
(-1/3) * [ 5 -2 ; -4 1 ]
# Out:
# 2×2 Matrix{Float64}:
#  -1.66667   0.666667
#   1.33333  -0.333333

# %%
inv( X )
# Out:
# 2×2 Matrix{Float64}:
#  -1.66667   0.666667
#   1.33333  -0.333333

# %%
ϵ, v = eigen( X )
# Out:
# Eigen{Float64, Float64, Matrix{Float64}, Vector{Float64}}
# values:
# 2-element Vector{Float64}:
#  -0.4641016151377544
#   6.464101615137754
# vectors:
# 2×2 Matrix{Float64}:
#  -0.806898  -0.343724
#   0.59069   -0.939071

# %%
v1 = v[1:2,1]; # gets the first column of v
norm( ( X - ϵ[1] * Diagonal([1, 1]) ) * v1 )
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ### Functions

# %%
f = x -> cos( x );
f( π )
# Out:
# -1.0

# %%
# vectorisation = entry-wise functuions --> use dot!
f.( [-π, 0, π] )
# Out:
# 3-element Vector{Float64}:
#  -1.0
#   1.0
#  -1.0

# %%
# you can also specify the vectorisation at the start:
@. f( [-π, 0, π] )
# Out:
# 3-element Vector{Float64}:
#  -1.0
#   1.0
#  -1.0

# %% [markdown]
# In order to plot functions we need the ```Plots``` package and, in order to write $\LaTeX$ in the titles and labels, we need ```LaTeXStrings```.

# %%
using Plots, LaTeXStrings

# %%
g(x) = x/exp(x)
plot( g, -5, 1, label="hello" )

# %%
X = -5:.01:1;
Y = X .* exp.(X) ;
 
plot( X, Y; 
    label = L"f(w) = w e^w", 
    xlabel = L"w", ylabel = "not latex", 
    title = "L\"\" is a LaTeX string and \"\" a normal string" )

# %%
#| label: fig-1
#| fig-cap: "Ploting two functions on one graph"

X = range(0, 10, length=100)
Y1 = @. sin(X) / X
Y2 = cos.(X)
plot( X, [Y1 Y2], 
        xlabel=L"x", 
        label=[L"\frac{\sin x}{x}" L"\cos x"], 
        linewidth=[4 2], 
        lc=[:green :blue])

# %% [markdown]
# In @fig-1, you can see two graphs!
#
# ::: {.callout-note}
#
# If you are looking at the code, don't worry about the ```@fig-1``` or the ```::: {.callout-note}``` syntax - this adds the html/css elements so that the webpage looks nicer.
#
# :::

# %% [markdown]
# ```!``` is like "hold on" in Matlab (if you are familar with that!)

# %%
#| label: fig-2
#| fig-cap: "Ploting functions"

f3(x) = 1 / (1 + x^2);
f4(x) = 1 / (1 + sin(x)^2);
plot(f3, -π, π, 
        lw=3, 
        label = L"f_1(x) = \frac{1}{1+x^2}");
plot!(f4, -π, π, 
        lw = 3, 
        label = L"f_2(x) = \frac{1}{1+\sin^2(x)}", 
        size = (600, 250), legend = :outertopright )

# %% [markdown]
# ## Math 5485
#
# * Chapter 1: <a href="lecture01.html#sec-chapter-1" class="btn btn-outline-primary btn-sm"><i class="bi bi-book"></i> Basics of Numerical Analysis</a>
# * Chapter 2: Solving Nonlinear Equations in 1d
# * Chapter 3: Polynomial Interpolation
# * Chapter 4: Numerical Integration
# * Chapter 5: Linear systems of equations

# %% [markdown]
# ## Chapter 1: Basics of Numerical Analysis {#sec-chapter-1}
#
# - Absolute and relative error
# - Rate of convergence
# - Using plots to show rate of convergence

# %% [markdown]
# Suppose we approximate $x$ with $\widetilde{x}$. Here, $x$ could be e.g. a root (or fixed point) of a function, the value of an integral, the solution of an ODE or PDE evaluated at a point, .... .

# %% [markdown]
# ::: {#def-error}
# # Errors
#
# We define:
#
# \begin{align}
# \text{Actual error:} &\quad x - \widetilde{x} \\
# \text{Absolute error:} &\quad |x - \widetilde{x}|
# \end{align}
#
# And when $x \neq 0$, the relative error is:
#
# \begin{align}
# \text{Relative error:} \quad \frac{|x - \widetilde{x}|}{|x|}
# \end{align}
#
# :::

# %% [markdown]
# ::: {#exm-errors}
#
# If $x = 1.5$ and $\widetilde{x} = 1$, then the absolute error is $0.5$ and the relative error is $\frac{0.5}{1.5} = \frac13$.
#
# If $x = 1.5 \times 10^{42}$ and $\widetilde{x} = 10^{42}$, then the absolute error is $0.5 \times 10^{42}$ and the relative error is $\frac13$.
#
# If $x = 1.5 \times 10^{-42}$ and $\widetilde{x} = 10^{-42}$, then the absolute error is $0.5 \times 10^{-42}$ and the relative error is $\frac13$.
#
# :::

# %% [markdown]
# The relative error is a better measure for small or large $x$:

# %% [markdown]
# ::: {#exm-Planck}
#
# Approximating Planck's constant $6.62607015 \times 10^{-34} \text{m}^2 \text{kg } \text{s}^{-1}$ with $0 \text{m}^2 \text{kg } \text{s}^{-1}$ would give an absolute error of $\approx 6 \times 10^{-34}$ (which seems small) but a relative error of $1$. In practice $0$ is a bad approximation to Planck's constant!
#
# :::

# %% [markdown]
# ::: {#def-acc-digits}
# # Number of correct significant digits
#
# Suppose $x \not= 0$ is approximated by $\widetilde{x}$. Then, we say this approximation is accurate to $n$ significant digits if
#
# $$\left| \frac{x-\widetilde{x}}{x} \right| \leq 5 \times 10^{-n}.$$
#
# :::

# %% [markdown]
# ::: {#exm-e}
#
# Approximating $e := \lim_{n\to\infty} \big( 1 + \frac1n \big)^n \approx 2.7182818.....$ with $3, 2.7,$ and $2.718$ gives
#
# \begin{align}
#     \left| \frac{e-\widetilde{x}}{e} \right| = 1.04 \times 10^{-1}, \quad 0.673 \times 10^{-2}, \quad 0.104 \times 10^{-3},
# \end{align}
#
# respectively.

# %%
e = exp(1)
abs( (e-3)/e ), abs( (e-2.7)/e ), abs( (e-2.718)/e )
# Out:
# (0.10363832351432703, 0.006725508837105614, 0.00010367889601972718)

# %% [markdown]
# :::
#
# ::: {#rem-sig-dig}
# # Number of correct significant digits
#
# Suppose $x \not= 0$ is approximated by $\widetilde{x}$. Some people say that this approximation is accurate to
#
# $$\eta := - \log_{10} \left| \frac{x-\widetilde{x}}{x} \right|$$
#
# significant digits.
#
# :::

# %% [markdown]
# ::: {#exr-eta}
#
# [](../exercises/bank.html#bank-exr-eta)
#
# Compute $\eta$ for approximating $e$ with $3$, $2.7$, and $2.718$.
#
# ::: {.exercise-solution style="display: none;"}
#
# We have

# %%
η( x, x_tilde ) = - log10( abs(x-x_tilde)/abs(x) )
η( exp(1), 3 ), η( exp(1), 2.7 ), η( exp(1), 2.718 )
# Out:
# (0.9844796209116626, 2.172274852323722, 3.984309635847452)

# %% [markdown]
# :::
# :::

# %% [markdown]
# We now consider a sequence of approximations $x_n$ converging to $x$. That is, for all $\varepsilon > 0$, there exists $N=N(\varepsilon)$ such that $|x - x_n| < \varepsilon$ for all $n > N$. In numerical analysis, we are interested in *(i)* whether our numerical schemes converge, and *(ii)* the rate of convergence:

# %% [markdown]
# ::: {#def-rate-convergence}
# # Rate of convergence
#
# Suppose $\varepsilon_n \geq 0$ and $(\varepsilon_n) \to 0$. Then, $x_n \to x$ with rate $O(\varepsilon_n)$ if there exist $C$ and $N$ such that
#
# $$
# |x - x_n| \leq C\varepsilon_n
# $$
#
# for all $n > N$. We also write $x_n = x + O(\varepsilon_n)$.
#
# :::

# %% [markdown]
# ::: {#exr-rate-1}
#
# [](../exercises/bank.html#bank-exr-rate-1)
#
# Show that $\frac{n + \cos(n)}{n^2} = O(\frac1n)$ and $\frac{n^2+3}{n^{42}} = O(\frac1{n^{40}})$.
#
# ::: {.exercise-solution style="display:none;"}
#
# Since $\cos(n) \leq n$ for all $n \in \mathbb{N}$, we have
#
# \begin{align}
#     \frac{n + \cos n}{n^2}
#     %
#     \leq \frac{2n}{n^2} = \frac{2}{n}.
# \end{align}
#
# That is, $\frac{n + \cos n}{n^2}$ is bounded above by a constant multiple of $n^{-1}$ so $\frac{n + \cos n}{n^2} = O(n^{-1})$.
#
# Similarly, $3 \leq 3n^2$ so $\frac{n^2 + 3}{n^{42}} \leq \frac{4}{n^{40}}$.
#
# :::
#
# :::

# %% [markdown]
# When plotting graphs, $O(n^{-k})$ decay (that is, **algebraic** decay) can be seen as straight lines on log-log plots ($-k$ is the slope in such graphs):

# %%
N = 1:100;
plot( N.^(-1) ;
    xlabel="n", xaxis=:log, yaxis=:log, 
    linestyle = :dot, lw=2, label = L"n^{-1}")
plot!( N.^(-2); 
    linestyle = :dot, lw=2, label = L"n^{-2}")
plot!( N.^(-5); 
    linestyle = :dot, lw=2, label = L"n^{-5}")

# %% [markdown]
# On the other hand, $O(e^{-c N})$ (that is, **exponential** decay) can be seen as straight lines on a semi-log y plot (and $-c$ is the gradient):

# %%
plot( exp.(-N);
    xlabel="n", yaxis=:log, 
    linestyle = :dot, lw=2, label = L"e^{-n}")
plot!( exp.(-2 .* N ); 
    linestyle = :dot, lw=2, label = L"e^{-2n}")
plot!( exp.(-5 .* N ); 
    linestyle = :dot, lw=2, label = L"e^{-5n}")

# %% [markdown]
# :::{.callout-tip}
# # TO-DO
#
# * Assignment 1: Due Wednesday (Install Julia),
# * Exercises (below)
# * (Sign-up to office hours if you like)
#
# :::

# %% [markdown]
# ## Exercises
#
# ::: {#exr-e title="Approximating Euler's constant"}
#
# [](../exercises/bank.html#bank-exr-e)
#
# Let $e$ denote Euler's constant.
#
# 1. $e_N := \big( 1 + \frac{1}{N} \big)^N$ is an approximation $e$. What is the error, absolute error, and relative error in approximating $e$ with $e_N$ for $N = 1,2,...,10$? What are the number of accurate digits in this approximation?
# 2. What is the rate of convergence of $e_N$ to $e$?
#
# ::: {.exercise-solution style="display:none;"}
#
# Let's define $e$ and the sequence of errors $|e - e_N|$:

# %%
e = exp(1)

N = 1:100;
err = @. abs( e - (1 + 1/N)^N );

# %% [markdown]
# The error is equal to the absolute error in this case and is given by

# %%
err[1:10]
# Out:
# 10-element Vector{Float64}:
#  0.7182818284590451
#  0.4682818284590451
#  0.34791145808867485
#  0.2768755784590451
#  0.22996182845904567
#  0.19665545671693163
#  0.17178213141833298
#  0.1524973145086972
#  0.13710703674584712
#  0.12453936835904278

# %% [markdown]
# Computing the relative errors give

# %%
err[1:10] ./ e
# Out:
# 10-element Vector{Float64}:
#  0.26424111765711533
#  0.17227125736425472
#  0.12798947277880338
#  0.10185683307753335
#  0.08459822894427681
#  0.07234549952033957
#  0.0631951145094156
#  0.05610062684160521
#  0.05043886005873465
#  0.045815473235769066

# %% [markdown]
# Since $0.0458... = 4.58... \times 10^{-2} \leq 5 \times 10^{-2}$, $e_{10}$ is correct to $2$ significant (decimal) digits.
#
# One can also compute the $\eta = - \log_{10} |\frac{e - e_N}{e}|$:

# %%
- log10.( err[1:10]/e )
# Out:
# 10-element Vector{Float64}:
#  0.5779996023832055
#  0.7637871764659977
#  0.8928257498997241
#  0.992009830990522
#  1.072638728778693
#  1.1405884803607715
#  1.199316494876063
#  1.2510322861176486
#  1.2972347372416126
#  1.338987823174671

# %% [markdown]
# Looking at the following plot, we can see that $| e - e_N | = O(N^{-1})$:

# %%
plot( err ;
    xaxis=:log, yaxis=:log, xlabel=L"N", title="absolute error", legend=false, lw=2, m=2 )
plot!( N.^(-1), color=:black, linestyle=:dash, label = L"n^{-1}" )

# %% [markdown]
# :::
#
# :::

# %% [markdown]
# ::: {#exr-Euler-Mascheroni title="Approximating Euler-Mascheroni constant"}
#
# [](../exercises/bank.html#bank-exr-Euler-Mascheroni)
#
# Euler-Mascheroni constant, $\gamma$, is defined as the limit of $\gamma_n = \sum_{k=1}^n \frac{1}{k} - \log n$ as $n \to \infty$.
#
# 1. What is the absolute error in approximating $\gamma$ with $\gamma_{1000}$?
# 2. What is the rate of convergence of $\gamma_n$ to $\gamma$?
# 3. [This was just so that we can remember some calculus and also rigorously prove the rate of convergence that we have seen above using a rigorous error estimate]
#    Prove that $|\gamma - \gamma_n| \leq \frac1n$.
#
# ::: {.exercise-solution style="display: none;"}
#
# First, we define the Euler-Mascheroni constant:

# %%
γ = Base.MathConstants.eulergamma
# Out:
# γ = 0.5772156649015...

# %% [markdown]
# ... and compute the absolute error in approximating $\gamma$ with $\gamma_{1000}$:

# %%
Nmax = 1000;

N = 1:Nmax;
γN = zeros( Nmax );
γN[1] = 1;
for n ∈ 2:Nmax
    γN[n] = (1/n) + γN[n-1] + log( (n-1)/n );
end

println( "γ₁₀₀₀ = ", γN[1000] )
println( "Abs. error = " , abs( γ - γN[1000] ) )
# Out:
# γ₁₀₀₀ = 0.5777155815682078
# Abs. error = 0.0004999166666749266

# %% [markdown]
# Here's a plot of the absolute errors on a log-log; the gradient matches $O(N^{-1})$:

# %%
plot( γN .- γ , xaxis=:log, yaxis=:log , legend = false, lw = 2, m=2)   
plot!( N.^(-1) , linestyle=:dash)

# %% [markdown]
# *Proof.* First, notice that
#
# \begin{align}
#     \gamma_n - \gamma_N
#     %
#     &= \log \frac Nn - \sum_{k=n+1}^N \frac{1}{k}\\
#     %
#     &= \sum_{k=n+1}^N \left( \log \frac{k}{k-1} - \frac{1}{k} \right).
# \end{align}
#
# Here, $\frac1k$ is the area under the rectangle with base $[k-1,k]$ and height $\frac1k$ and $\log \frac{k}{k-1}$ is the integral of $\frac1x$ between $x = k-1$ and $x = k$:

# %%
k=3; x = range(k-1,k, 100);
plot( x, [x.^(-1) ones(100)./k (x .+ 1).^(-1)], 
    ylims=(0,1/(k-1)), 
    label=[L"y=\frac{1}{x}" L"\frac{1}{k}" L"y=\frac{1}{x+1}"] )

# %% [markdown]
# In the graph above, $\frac1k$ is the area under the red line, $\log \frac{k}{k-1}$ is the area under the blue line. We upper bound the absolute value of the error between these areas, by computing the area between $y = \frac1x$ and $y=\frac1{x+1}$:
#
# \begin{align}
#     0 \leq \gamma_n - \gamma_N
#     %
#     &\leq \sum_{k=n+1}^N \left( \log \frac{k}{k-1} - \frac{1}{k} \right) \\
#     %
#     &\leq \sum_{k=n+1}^N \int_{k-1}^k \left( \frac{1}{x} - \frac{1}{x + 1} \right) \mathrm{d}x
#     %
#     = \int_{n}^\infty \frac{1}{x(x+1)} \mathrm{d}x \\
#     %
#     &\leq \int_{n}^\infty \frac{1}{x^2} \mathrm{d}x = \frac1n
# \end{align}
#
# Here, we have shown that $(\gamma_n)$ is a Cauchy sequence and thus it converges, and we have the same estimate for $\gamma_n - \gamma$ by taking the limit in $N$. $\text{    }\square$
#
# :::
# :::

# %% [markdown]
# ::: {#exr-pi-artan title="Assignment 1, Fall 2025, 30 pts"}
#
# [](../exercises/bank.html#bank-exr-pi-artan)
#
# *Assignment 1, Fall 2025, 30 pts* The quantities
#
# \begin{align}
# \pi_N := 4 \sum_{n=0}^N \frac{(-1)^n}{2n+1}
# \end{align}
#
# approximate $\pi$ by using the Taylor expansion of $\arctan$ together with the fact that $\pi = 4 \arctan(1)$.

# %%
using Plots, LaTeXStrings

Nmax = 100;
Ninter = 1:Nmax;

# vectors of length Nmax
p = zeros( Nmax ); q = zeros( Nmax );
p[1] = 4 * ( 1 - 1/3 ) ;
q[1] = abs( p[1] - π );
for N in 2:Nmax
    p[N] = p[N-1] + 4 * (-1)^N/(2*N + 1);
    q[N] = abs( p[N] - π );
end

plot(p, legend=false, xlabel="N", title=L"\pi_N")

# %% [markdown]
# Based on the following graph, what is the rate of convergence of this particular approximation to $\pi$? Why do we use a log-log scale for this graph?

# %%
plot( q , xaxis=:log, yaxis=:log, xlabel=L"N", title="absolute error", legend=false)
plot!( Ninter.^(-1) , ls=:dash)

# %% [markdown]
# ::: {.exercise-solution style="display: none;"}
#
# We have $|\pi - \pi_N| = O(N^{-1})$. The log-log plot makes this behaviour easy to see.
#
# In fact, one can show that
#
# \begin{align}
#     |\pi - \pi_N| &= 4 \int_{0}^1 \frac{t^{2(N+1)}}{1 + t^2} \mathrm{d}t\nonumber\\
#     %
#     &\leq \frac{4}{2N+3}.
# \end{align}
#
# :::
#
# :::
