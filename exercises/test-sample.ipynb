# %% [markdown]
# ---
# title: "Sample in-class test"
# subtitle: ""
# date: "2026-09-23"
# format:
#   html: default
#   pdf: default
# ---

# %% [markdown]
# <div style='padding: 10px; border: 5px solid black;'><strong>NAME:</strong></div>
#
# <div style='padding: 10px; border: 5px solid black; border-top: 0px'><strong>STUDENT NUMBER:</strong></div>
#
# ---
#
# Time allowed: **15 mins**
#
# **Please label any paper you use with your name and student number**
#
# Electronic devices are not needed and not permitted in this test.
#
# ---

# %% [markdown]
# 1. **[5 points]** Let $x_n = \frac{1 + n^2}{ 2 n^3 } \cos n$.
#    For which of the following sequences $(\varepsilon_n)$ do we have $x_n = O(\varepsilon_n)$ as $n\to\infty$?
#    Please select all that apply.
#
# <div style="border: 1px solid black; margin:10px">
#
# <div style='padding: 10px; border: 1px solid black; border-left:50px solid lightgray; height:50px;'>
#
# $\varepsilon_n = e^{-n}$
# </div>
#
# <div style='padding: 10px; border: 1px solid black; border-left:50px solid lightgray; height:50px;'>
#
# $\varepsilon_n = n^{-2}$
# </div>
#
# <div style='padding: 10px; border: 1px solid black; border-left:50px solid lightgray; height:50px;'>
#
# $\varepsilon_n = n^{-1}$
# </div>
#
# <div style='padding: 10px; border: 1px solid black; border-left:50px solid lightgray; height:50px;'>
#
# $\varepsilon_n = 1$
# </div>
#
# <div style='padding: 10px; border: 1px solid black; border-left:50px solid lightgray; height:50px;'>
#
# $\varepsilon_n = n$
# </div>
#
# </div>
#
#
# 2. **[5 points]** Recall that Float64 uses binary precision $k = 52$. How many floating point numbers are in the interval $[64, 128)$?
#
# <div style="border: 1px solid black; margin:10px; height:150px">
#
# </div>
#
# 3. **[5 points]** Let us define
#
# \begin{align*}
#    f(x) = \frac{\sqrt{1+x}-1}{x}, \qquad g(x) = \frac{1}{\sqrt{1+x} + 1}.
# \end{align*}
#
# One may verify that $f$ and $g$ are mathematically identical (but you don't have to). The following table is the output of evaluating $f$ and $g$ on $\{10^{-14}, 10^{-15}, 10^{-16}\}$ in double precision floating point. Why are the function values different?

# %%
#| echo: false

f = x -> ( sqrt(1 + x) - 1 ) / x
g = x-> 1/( 1 + sqrt(1 + x) )

t = [1e-14; 1e-15; 1e-16];
   
println( "                         f(x)                  g(x)" )
println( "x = 10^(-14):     ", f(t[1]), "    ",    g(t[1]) )
println( "x = 10^(-15):     ", f(t[2]), "   ",    g(t[2]) )
println( "x = 10^(-16):     ", f(t[3]), "                   ",    g(t[3]) )
# Out:
#                          f(x)                  g(x)
# x = 10^(-14):     0.4884981308350689    0.4999999999999988
# x = 10^(-15):     0.44408920985006256   0.4999999999999999
# x = 10^(-16):     0.0                   0.5

# %% [markdown]
# <div style="border:1px black solid; height:100px">
#
# </div>
